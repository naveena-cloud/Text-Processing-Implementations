# %%
def tokenize_text(text):
    tokens = text.split()
    return tokens

if __name__ == "__main__":
    text = "Natural language processing enables machines to understand and interpret human language."

    tokens = tokenize_text(text)

    print("Tokens:")
    print(tokens)
# Out:
# Tokens:
# ['Natural', 'language', 'processing', 'enables', 'machines', 'to', 'understand', 'and', 'interpret', 'human', 'language.']
